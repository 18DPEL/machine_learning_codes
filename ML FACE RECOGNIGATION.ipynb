# %% [markdown]
# # Question 1. write a program to using knn theom find  pridicting karnel value

# %%
import numpy as np
import matplotlib.pyplot as pld

# %%
import cv2
import numpy as np
import matplotlib.pyplot as pld

# %%
img=cv2.imread("user-1.png")
pld.imshow(img)

# %%
data=np.array([[0,1,0],[1,0,0],[0,0,1]])
img2=cv2.filter2D(img,-1,data)
pld.imshow(img2)

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

pld.imshow(gray_img)

# %%
img.shape
# Out:
# (200, 200, 3)
